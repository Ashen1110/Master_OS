# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# ALU remainder section size
# run for 10 sec
# with user num = 100
ncs_size = [160, 120, 80, 40, 20, 10, 5, 2.5, 1]
inuse_only = [40.0, 52.9, 77.9, 89.6, 44.9, 35.1, 38.6, 81.1, 76.2]
plock = [40.2, 52.8, 74.1, 71.3, 60.7, 55.9, 56.8, 46.2, 42.1]
ticket = [40.1, 52.3, 57.1, 55.2, 55.0, 55.5, 55.5, 55.4, 54.9]
mcs = [40.0, 52.3, 73.1, 76.2, 77.4, 77.4, 78.0, 78.2, 78.6]

mutex = [39.7, 51.5, 49.8, 39.7, 35.1, 33.6, 32.4, 32.0, 32.8]
semaphore = [39.6, 50.9, 46.2, 35.6, 32.1, 31.5, 30.2, 30.2, 28.8]

values = range(len(ncs_size))
plt.figure(figsize=(15,5),dpi=100,linewidth = 2)
plt.plot(values, inuse_only, color="crimson", linestyle="-", linewidth="2", markersize="12", marker=".", label="inuse_only")
plt.plot(values, mcs, color="seagreen", linestyle="-", linewidth="2", markersize="12", marker=".", label="MCS")
plt.plot(values, plock, color="gold", linestyle="-", linewidth="2", markersize="12", marker=".", label="plock")
plt.plot(values, ticket, color="cornflowerblue", linestyle="-", linewidth="2", markersize="12", marker=".", label="ticket")
plt.plot(values, mutex, color="darkorange", linestyle="-", linewidth="2", markersize="12", marker=".", label="pthread_mutex")
plt.plot(values, semaphore, color="plum", linestyle="-", linewidth="2", markersize="12", marker=".", label="binary semaphore")


plt.xticks(values, ncs_size)
plt.xlabel('remainder section size (k)', fontsize="18")
plt.ylabel('locks per second (10,000)', fontsize="18")

title = "Locks per second under different loads"
plt.suptitle(title,  y=1.02, fontsize="20")
sub = " Critical section with ALU"
plt.title(sub, y=1, fontsize="16")

plt.legend()
plt.show()

# %%
#ALU fairness
# ncs_size = 0, threads_num = 64
# user_num = 100
# run for 10 sec
threads = np.linspace(0, 63, 64)
inuse_only = [660,836,570,697,882,1081,652,788,197268,333904,80604,224302,174297,289193,78084,207231,133702,230551,53718,151662,98230,176253,42542,121854,105820,181260,44690,123450,134917,233446,61008,150580,718,881,534,675,712,796,413,594,206136,329189,86518,218318,180468,283734,82133,211296,137821,222735,58500,155566,99035,173620,46869,124541,109267,183175,49527,126674,139277,231529,65339,155426]
plock = [47505,87886,79325,106342,52354,88068,83609,101999,52789,88334,66002,119298,50998,83120,61913,114032,65187,115469,84478,150081,72271,128199,94800,167552,48525,89519,62653,111791,50112,93432,65660,117351,48128,90221,79402,113234,52853,89703,84298,101243,51349,88687,66140,121416,50024,84259,62446,114508,63967,115101,85819,152541,70690,128027,95466,170008,47773,85088,62576,115161,48812,88219,65555,121194]
ticket = [81916,81920,81894,81887,81878,81874,81935,81867,81863,81860,81848,81848,81848,81848,81848,81848,81844,81844,81845,81844,81843,81843,81843,81843,81842,81842,81842,81841,81842,81841,81841,81841,81841,81841,81841,81842,81842,81842,81842,81842,81843,81843,81844,81845,81845,81847,81847,81849,81850,81851,81852,81854,81856,81858,81861,81863,81867,81870,81875,81881,81896,81909,81925,84991]
mcs = [134508,134513,134673,134516,134514,134499,134490,134482,134463,134462,134437,134437,134444,134442,134438,134441,134436,134435,134423,134430,134429,134427,134423,134423,134426,134428,134423,134424,134427,134426,134425,134422,134429,134430,134427,134432,134433,134432,134434,134436,134436,134439,134394,134533,134535,134538,134541,134542,134554,134550,134553,134554,134566,134571,134537,135342,135315,135323,135335,135344,137729,137755,137853,160047]
mutex = [138276,109692,120163,132061,132639,96946,126727,124899,29836,28080,27963,28793,28492,27035,26854,24969,29292,23389,27150,25659,32185,25089,29809,29164,26833,30523,29243,33274,28436,28948,25805,25079,125973,104513,122533,134785,134881,106316,130359,125445,30272,29025,26650,27604,29773,24442,27476,25837,32725,23929,27714,28649,30107,29020,28365,31598,27157,27958,29955,29314,28463,29921,28749,29212]
semaphore = [28492,25686,27458,39299,22774,19535,23232,21952,106764,94093,115934,106531,102112,82445,99356,99156,21098,19797,18425,21502,29398,23530,27085,26555,26931,29780,24514,25463,21694,23638,24729,20462,33674,26326,32391,32253,23630,21803,30945,24815,109464,88205,109241,108414,100563,80959,98760,102977,25270,20569,20909,25485,32738,24734,32550,29862,23732,23286,26423,24714,20905,22068,20454,24269]

plt.figure(figsize=(15,5),dpi=100,linewidth = 2)
plt.plot(threads, inuse_only, color="crimson", linestyle="-", linewidth="2", markersize="12", marker=".", label="inuse_only")
plt.plot(threads, mcs, color="seagreen", linestyle="-", linewidth="2", markersize="12", marker=".", label="mcs")
plt.plot(threads, plock, color="gold", linestyle="-", linewidth="2", markersize="12", marker=".", label="plock")
plt.plot(threads, ticket, color="cornflowerblue", linestyle="-", linewidth="2", markersize="12", marker=".", label="ticket")
plt.plot(threads, mutex, color="darkorange", linestyle="-", linewidth="2", markersize="12", marker=".", label="pthread_mutex")
plt.plot(threads, semaphore, color="plum", linestyle="-", linewidth="2", markersize="12", marker=".", label="binary semaphore")


plt.xlim(0, 65)

plt.xlabel('threads number on cores', fontsize="18")
plt.ylabel('times to enter CS', fontsize="18")
title = "Times of threads enter CS\n"
plt.suptitle(title,  y=1.02, fontsize="20")
sub = "Critical section with ALU and remainder section size = 0"
plt.title(sub, fontsize="16")

plt.legend()
plt.show()

# %%
# ALU oversubscribe
#x_threads = [64,96,128,256,384, 512], ncs_size = 2000
spinlocks = ['inuse_only', 'mcs', 'plock', 'ticket', 'pthread_mutex', 'binary_semaphore']
thread64 = [738379, 869575,556451,521936, 325090, 299942]
thread96 = [740543, 308022,321253,318450, 315230, 288715]
thread128 = [729639,304442,253023,302181, 305899, 281994]
thread256 = [715372,178520,122789,180964, 315072, 302584]
thread384 = [690685,130040,89158,132163, 315758, 293258]
thread512 = [720130,102788,67006,105257, 315995, 295654]

x = np.arange(len(spinlocks))
width = 0.1

plt.figure(figsize=(16,8),dpi=100,linewidth = 2)

plt.bar(x, thread64, width, color='midnightblue', label='64 threads')
plt.bar(x+width, thread96, width, color='darkblue', label='96 threads')
plt.bar(x+width*2, thread128, width, color='royalblue', label='128 threads')
plt.bar(x+width*3, thread256, width, color='cornflowerblue', label='256 threads')
plt.bar(x+width*4, thread384, width, color='lightsteelblue', label='384 threads')
plt.bar(x+width*5, thread512, width, color='lavender', label='512 threads')

plt.xticks(x + width*5/3 , spinlocks, fontsize="14")
plt.ylabel('locks per second', fontsize="18")
plt.suptitle('Oversubscribe', fontsize="24")
sub = "Critical section with ALU and remainder section size = 2000"
plt.title(sub, fontsize="16")
plt.legend(bbox_to_anchor=(1,1), loc='upper left')
plt.show()

# %%
# ALU critical section size
# run for 10 sec
# with ncs_size = 2000
user_num = [100, 1000, 10000, 100000, 1000000]
inuse_only = [76.2, 23.4, 3.4, 0.36, 0.035]
plock = [43.8, 25.7, 3.5, 0.31, 0.027]
ticket = [39.1, 15.7, 2.1, 0.22, 0.024]
mcs = [41.3, 15.2, 2.1, 0.22, 0.024]
mutex = [30.2, 13.1, 2.1, 0.23, 0.024]
semaphore = [29.4, 13.4, 2.1, 0.24, 0.024]

values = range(len(user_num))
plt.figure(figsize=(15,5),dpi=100,linewidth = 2)
plt.plot(values, inuse_only, color="crimson", linestyle="-", linewidth="2", markersize="12", marker=".", label="inuse_only")
plt.plot(values, mcs, color="seagreen", linestyle="-", linewidth="2", markersize="12", marker=".", label="MCS")
plt.plot(values, plock, color="gold", linestyle="-", linewidth="2", markersize="12", marker=".", label="plock")
plt.plot(values, ticket, color="cornflowerblue", linestyle="-", linewidth="2", markersize="12", marker=".", label="ticket")
plt.plot(values, mutex, color="darkorange", linestyle="-", linewidth="2", markersize="12", marker=".", label="pthread_mutex")
plt.plot(values, semaphore, color="plum", linestyle="-", linewidth="2", markersize="12", marker=".", label="binary semaphore")


plt.xticks(values, user_num)
plt.xlabel('critical section size (k)', fontsize="18")
plt.ylabel('locks per second (10,000)', fontsize="18")

title = "Locks per second under different loads"
plt.suptitle(title,  y=1.02, fontsize="20")
sub = "Critical section with ALU and remainder section size = 2000"
plt.title(sub, y=1, fontsize="16")

plt.legend()
plt.show()

# %%
# ALU critical section size
# run for 10 sec
# with ncs_size = 2000
user_num = [10000, 100000, 1000000]
inuse_only = [3400, 360, 35]
plock = [3500, 310, 27]
ticket = [2100, 220, 24]
mcs = [2100, 220, 24]
mutex = [2100, 230, 24]
semaphore = [2100, 240, 24]

values = range(len(user_num))
plt.figure(figsize=(15,5),dpi=100,linewidth = 2)
plt.plot(values, inuse_only, color="crimson", linestyle="-", linewidth="2", markersize="12", marker=".", label="inuse_only")
plt.plot(values, mcs, color="seagreen", linestyle="-", linewidth="2", markersize="12", marker=".", label="MCS")
plt.plot(values, plock, color="gold", linestyle="-", linewidth="2", markersize="12", marker=".", label="plock")
plt.plot(values, ticket, color="cornflowerblue", linestyle="-", linewidth="2", markersize="12", marker=".", label="ticket")
plt.plot(values, mutex, color="darkorange", linestyle="-", linewidth="2", markersize="12", marker=".", label="pthread_mutex")
plt.plot(values, semaphore, color="plum", linestyle="-", linewidth="2", markersize="12", marker=".", label="binary semaphore")


plt.xticks(values, user_num)
plt.xlabel('critical section size (k)', fontsize="18")
plt.ylabel('locks per second (10,000)', fontsize="18")

title = "Locks per second under different loads"
plt.suptitle(title,  y=1.02, fontsize="20")
sub = "Critical section with ALU and remainder section size = 2000"
plt.title(sub, y=1, fontsize="16")

plt.legend()
plt.show()

# %%
# ALU critical section size
# run for 10 sec
# with ncs_size = 2000
spinlocks = ['inuse_only', 'mcs', 'plock', 'ticket', 'pthread_mutex', 'binary_semaphore']
#user_num10000 = [3400, 2100,3500,2100, 2100, 2100]
user_num100000 = [360, 220,310, 220, 230, 240]
user_num1000000 = [35,24,27,24, 24, 24]

x = np.arange(len(spinlocks))
width = 0.1

plt.figure(figsize=(16,8),dpi=100,linewidth = 2)

plt.bar(x, user_num100000, width, color='royalblue', label='user_num 100000')
plt.bar(x+width, user_num1000000, width, color='cornflowerblue', label='user_num 1000000')
#plt.bar(x+width*2, user_num1000000, width, color='lightsteelblue', label='user_num 1000000')

plt.xticks(x + width*3/2 , spinlocks, fontsize="14")
plt.ylabel('locks per second', fontsize="18")

title = "Locks per second under different loads"
plt.suptitle(title,  y=1.02, fontsize="20")
sub = "Critical section with ALU and remainder section size = 2000"
plt.title(sub, y=1, fontsize="16")

plt.legend(bbox_to_anchor=(1,1), loc='upper left')
plt.show()

# %%
#### IO Section

# %%
# IO remainder section size
# run for 10 sec
# with user num = 100
ncs_size = [160, 120, 80, 40, 20, 10, 5, 2.5, 1]
inuse_only = [68.2, 67.5, 73.2, 74.8, 75.0, 73.8, 75.6, 76.1, 76.6]
plock = [71.2, 70.9, 76.0, 74.7, 75.3, 73.8, 80.8, 78.4, 78.2]
ticket = [57.9, 58.0, 57.6, 58.8, 60.2, 59.8, 61.7, 58.7, 60.3]
mcs = [58.3, 58.3, 58.9, 59.0, 61.4, 60.5, 58.9, 60.9, 58.9]
mutex = [25.5, 25.5, 26.9, 26.2, 28.3, 33.9, 45.7, 53.3, 61.4]
semaphore = [26.4, 28.3, 26.9, 29.0, 30.0, 32.4, 40.8, 51.3, 53.2]

values = range(len(ncs_size))
plt.figure(figsize=(15,5),dpi=100,linewidth = 2)
plt.plot(values, inuse_only, color="crimson", linestyle="-", linewidth="2", markersize="12", marker=".", label="inuse_only")
plt.plot(values, mcs, color="seagreen", linestyle="-", linewidth="2", markersize="12", marker=".", label="MCS")
plt.plot(values, plock, color="gold", linestyle="-", linewidth="2", markersize="12", marker=".", label="plock")
plt.plot(values, ticket, color="cornflowerblue", linestyle="-", linewidth="2", markersize="12", marker=".", label="ticket")
plt.plot(values, mutex, color="darkorange", linestyle="-", linewidth="2", markersize="12", marker=".", label="pthread_mutex")
plt.plot(values, semaphore, color="plum", linestyle="-", linewidth="2", markersize="12", marker=".", label="binary semaphore")


plt.xticks(values, ncs_size)
plt.xlabel('remainder section size (k)', fontsize="18")
plt.ylabel('locks per second (10,000)', fontsize="18")

title = "Locks per second under different loads"
plt.suptitle(title,  y=1.02, fontsize="20")
sub = " Critical section with FILE I/O"
plt.title(sub, y=1, fontsize="16")

plt.legend()
plt.show()

# %%
#IO fairness
# ncs_size = 0, threads_num = 64
# user_num = 100
# run for 10 sec
threads = np.linspace(0, 63, 64)
inuse_only = [8597,13971,4854,9504,2273,3709,1287,2489,31539,35014,15319,31876,41472,44202,18141,36404,6933,11656,3872,7954,2627,4274,1403,2944,1906,3039,1016,2007,5332,8859,2907,5919,8490,14080,4558,9291,2287,3631,1147,2352,28968,33926,14294,28842,37842,42910,17172,32738,6992,11756,3704,7975,2575,4212,1345,2837,1766,2950,1024,1897,5387,8796,2714,5831]
plock = [5362,6334,5859,9412,12448,14368,12946,21120,7765,11220,10184,13491,14465,20602,19024,24760,6856,8446,7744,12461,5484,6681,6031,9577,9483,12781,11634,18274,3952,5497,5061,7783,5372,6455,5809,9664,12228,14339,12956,21612,7798,10926,10052,13513,14492,19921,18505,24642,6806,8651,7903,12854,5450,6681,6157,10268,9564,11970,11069,17686,3961,5189,4701,7507]
ticket = [8034,8034,8030,8031,8030,8030,8030,8030,8029,8029,8029,8029,8029,8029,8029,8029,8029,8029,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028,8028]
mcs = [7996,7995,7990,7991,7991,7990,7990,7990,7989,7989,7989,7989,7988,7988,7988,7988,7988,7988,7987,7987,7987,7987,7987,7987,7987,7987,7987,7987,7987,7987,7987,7987,7987,7987,7987,7987,7987,7987,7987,7987,7987,7987,7987,7987,7989,7988,7988,7988,7989,7980,7988,8043,8043,8043,8044,8044,8044,8045,8045,8046,8046,8046,8047,8050]
semaphore = [9700,8097,7878,7937,8114,8192,8636,7736,9587,7813,7648,7395,7883,8578,8312,7848,8058,8836,8168,7518,8253,8049,9337,10211,8008,8813,7631,8901,9288,8476,8924,7981,8965,10290,8772,7853,8086,9871,9865,9250,9424,9031,9089,8836,9835,8597,9330,9891,8500,8669,8450,9149,10119,9143,9647,9626,9690,9943,9403,8810,8042,9061,9399,9560]
mutex = [8706,6858,6393,6837,6923,8809,7583,5979,6457,7868,5880,7701,8033,6961,7575,8561,7529,8499,7191,7496,6755,7135,7059,8727,6642,8105,6269,7346,7294,8129,8072,6026,7974,6634,7185,7965,6526,8195,6435,6702,6897,7701,7409,9655,6508,8061,8757,7942,6129,8541,7372,6213,7409,6584,7330,5368,7327,6439,7117,7142,6350,7390,6917,6345]

plt.figure(figsize=(15,5),dpi=100,linewidth = 2)
plt.plot(threads, inuse_only, color="crimson", linestyle="-", linewidth="2", markersize="12", marker=".", label="inuse_only")
plt.plot(threads, mcs, color="seagreen", linestyle="-", linewidth="2", markersize="12", marker=".", label="mcs")
plt.plot(threads, plock, color="gold", linestyle="-", linewidth="2", markersize="12", marker=".", label="plock")
plt.plot(threads, ticket, color="cornflowerblue", linestyle="-", linewidth="2", markersize="12", marker=".", label="ticket")
plt.plot(threads, mutex, color="darkorange", linestyle="-", linewidth="2", markersize="12", marker=".", label="pthread_mutex")
plt.plot(threads, semaphore, color="plum", linestyle="-", linewidth="2", markersize="12", marker=".", label="binary semaphore")


plt.xlim(0, 65)

plt.xlabel('threads number on cores', fontsize="18")
plt.ylabel('times to enter CS', fontsize="18")
title = "Times of threads enter CS\n"
plt.suptitle(title,  y=1.02, fontsize="20")
sub = "Critical section with FILE I/O and remainder section size = 0"
plt.title(sub, fontsize="16")

plt.legend()
plt.show()

# %%
# IO oversubscribe
#x_threads = [64,96,128,256,384, 512], ncs_size = 2000
spinlocks = ['inuse_only', 'mcs', 'plock', 'ticket', 'pthread_mutex', 'binary_semaphore']
thread64 = [68179, 52375,71118,52904,54196,50449]
thread96 = [45139, 37635,52754,39647,66845,50556]
thread128 = [45767,38170,38718,39691,70700,50099]
thread256 = [45349,35118,19457,35406,70670,50158]
thread384 = [45119,32131,13271,32605,67976,50330]
thread512 = [44627,30033,10432,31093,69703,48695]

x = np.arange(len(spinlocks))
width = 0.1

plt.figure(figsize=(16,8),dpi=100,linewidth = 2)

plt.bar(x, thread64, width, color='midnightblue', label='64 threads')
plt.bar(x+width, thread96, width, color='darkblue', label='96 threads')
plt.bar(x+width*2, thread128, width, color='royalblue', label='128 threads')
plt.bar(x+width*3, thread256, width, color='cornflowerblue', label='256 threads')
plt.bar(x+width*4, thread384, width, color='lightsteelblue', label='384 threads')
plt.bar(x+width*5, thread512, width, color='lavender', label='512 threads')

plt.xticks(x + width*5/3 , spinlocks, fontsize="14")
plt.ylabel('locks per second', fontsize="18")
plt.suptitle('Oversubscribe', fontsize="24")
sub = "Critical section with ALU and remainder section size = 2000"
plt.title(sub, fontsize="16")
plt.legend(bbox_to_anchor=(1,1), loc='upper left')
plt.show()

# %%
# IO critical section size
# run for 10 sec
# with ncs_size = 2000
user_num = [100, 1000, 10000, 100000, 1000000]
inuse_only = [44.4, 5.3, 0.52, 0.053, 0.0059]
plock = [77.9, 9.6, 0.95, 0.092, 0.0099]
ticket = [40.1, 5.3, 0.52, 0.052, 0.0058]
mcs = [39.7, 5.3, 0.52, 0.0052, 0.0060]
mutex = [54.5, 9.9, 1.4, 0.13, 0.013]
semaphore = [50.5, 8.9, 1.38, 0.14, 0.013]

values = range(len(user_num))
plt.figure(figsize=(15,5),dpi=100,linewidth = 2)
plt.plot(values, inuse_only, color="crimson", linestyle="-", linewidth="2", markersize="12", marker=".", label="inuse_only")
plt.plot(values, mcs, color="seagreen", linestyle="-", linewidth="2", markersize="12", marker=".", label="MCS")
plt.plot(values, plock, color="gold", linestyle="-", linewidth="2", markersize="12", marker=".", label="plock")
plt.plot(values, ticket, color="cornflowerblue", linestyle="-", linewidth="2", markersize="12", marker=".", label="ticket")
plt.plot(values, mutex, color="darkorange", linestyle="-", linewidth="2", markersize="12", marker=".", label="pthread_mutex")
plt.plot(values, semaphore, color="plum", linestyle="-", linewidth="2", markersize="12", marker=".", label="binary semaphore")


plt.xticks(values, user_num)
plt.xlabel('critical section size (k)', fontsize="18")
plt.ylabel('locks per second (k)', fontsize="18")

title = "Locks per second under different loads"
plt.suptitle(title,  y=1.02, fontsize="20")
sub = "Critical section with IO and remainder section size = 2000"
plt.title(sub, y=1, fontsize="16")

plt.legend()
plt.show()

# %%
# IO critical section size
# run for 10 sec
# with ncs_size = 2000
spinlocks = ['inuse_only', 'mcs', 'plock', 'ticket', 'pthread_mutex', 'binary_semaphore']
#user_num10000 = [520, 520,950,520, 1400, 1380]
user_num100000 = [53, 52,92, 52, 130, 140]
user_num1000000 = [5.9,5.8,9.9,5.8, 13, 13]

x = np.arange(len(spinlocks))
width = 0.1

plt.figure(figsize=(16,8),dpi=100,linewidth = 2)

plt.bar(x, user_num100000, width, color='royalblue', label='user_num 100000')
plt.bar(x+width, user_num1000000, width, color='cornflowerblue', label='user_num 1000000')
#plt.bar(x+width*2, user_num1000000, width, color='lightsteelblue', label='user_num 1000000')

plt.xticks(x + width*3/2 , spinlocks, fontsize="14")
plt.ylabel('locks per second', fontsize="18")

title = "Locks per second under different loads"
plt.suptitle(title,  y=1.02, fontsize="20")
sub = "Critical section with IO and remainder section size = 2000"
plt.title(sub, y=1, fontsize="16")

plt.legend(bbox_to_anchor=(1,1), loc='upper left')
plt.show()
