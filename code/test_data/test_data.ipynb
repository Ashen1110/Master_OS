# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# ncs_size
ncs_size = [160, 120, 80, 40, 20, 10, 5, 2.5, 1]
ron = [39.7, 52.2, 75.0, 124.3, 141.4, 121.3, 116.3, 114.1, 117.4]
plock = [40.2, 53.2, 77.4, 84.6, 71.8, 61.3, 62.8, 51.1, 46.4]
ticket = [40.1, 53.8, 65.5, 61.9, 61.8, 61.9, 62.1, 62.4, 65.0]
ron_plock = [39.6, 52.1, 74.9, 127.5, 151.2, 148.3, 146.8, 145.5, 143.9]
ron_ticket = [39.6, 52.1, 75.2, 128.8, 148.0, 144.9, 126.4, 121.7, 124.4]

values = range(len(ncs_size))
plt.figure(figsize=(15,5),dpi=100,linewidth = 2)
plt.plot(values, ron, color="crimson", linestyle="-", linewidth="2", markersize="12", marker=".", label="RON")
plt.plot(values, ron_plock, color="seagreen", linestyle="-", linewidth="2", markersize="12", marker=".", label="RON_Plock")
plt.plot(values, ron_ticket, color="navy", linestyle="-", linewidth="2", markersize="12", marker=".", label="RON_ticket")
plt.plot(values, plock, color="gold", linestyle="-", linewidth="2", markersize="12", marker=".", label="plock")
plt.plot(values, ticket, color="cornflowerblue", linestyle="-", linewidth="2", markersize="12", marker=".", label="ticket")


plt.xticks(values, ncs_size)
plt.xlabel('remainder section size (k)', fontsize="18")
plt.ylabel('locks per second (10,000)', fontsize="18")

title = "Locks per second under different loads"
plt.suptitle(title,  y=1.02, fontsize="20")
sub = " with 64 threads"
plt.title(sub, y=1, fontsize="16")

plt.legend()
plt.show()

# %%
#fairness
# ncs_size = 2000, threads_num = 64
threads = np.linspace(0, 63, 64)
ron = [1119626,1119564,1119610,1119603,1119617,1119616,1119615,1119592,1116785,1119604,1119608,1119608,1119607,1119604,1119606,1119607,1119714,1119701,1119738,1119749,1119982,1120248,1120063,1120021,1119608,1119609,1119613,1119612,1119613,1119613,1119614,1119617,1119606,1119619,1119611,1119620,1119613,1119600,1119603,1119604,1119609,1119590,1119606,1119605,1119606,1119607,1119524,1119607,1119967,1119982,1120116,1119980,1120253,1120166,1120074,1120353,1119611,1119611,1119612,1119612,1119717,1119697,1119701,1119728]
plock = [372255,377620,379712,369842,327441,323713,318196,323348,1638510,1442688,1622013,1455732,1472546,1472994,1719001,1565478,226732,219091,217851,223635,221968,222740,230327,225738,150238,156358,150517,146890,168686,165975,163390,162765,363737,364991,377806,364555,323119,334833,323326,311277,1405951,1641379,1686347,1439886,1531703,1581910,1473144,1479361,226368,217760,219339,225762,229329,216686,222103,227937,152563,157478,155921,155142,168616,172385,164748,165141]
ticket = [529938,529932,529865,529721,529252,529150,528973,529152,529871,528946,529788,529610,528975,528961,529913,529914,529188,529260,529931,530052,529443,530424,530309,530702,529153,528986,529932,529508,529214,529022,529082,530019,529302,529884,529645,529395,529575,529171,529883,528868,527068,529892,529909,529508,529222,529461,528865,529562,529195,529450,530227,529415,530773,529547,529757,529862,529869,529841,529293,529952,529445,529137,529321,530053,]

plt.figure(figsize=(15,5),dpi=100,linewidth = 2)
plt.plot(threads, ron, color="crimson", linestyle="-", linewidth="2", markersize="12", marker=".", label="RON")
plt.plot(threads, plock, color="seagreen", linestyle="-", linewidth="2", markersize="12", marker=".", label="plock")
plt.plot(threads, ticket, color="royalblue", linestyle="-", linewidth="2", markersize="12", marker=".", label="ticket")

plt.xlim(0, 65)

plt.xlabel('threads number on cores', fontsize="18")
plt.ylabel('times to enter CS', fontsize="18")
title = "Times of threads enter CS\n"
plt.suptitle(title,  y=1.02, fontsize="20")
sub = "with 64 threads and remainder section size = 2000"
plt.title(sub, fontsize="16")
plt.savefig('/home/ashen/Desktop/fairness_64.png')
plt.legend()
plt.show()

# %%
# fairness oversubcribe
# threads=128, ncs=2000
threads = np.linspace(0, 63, 64)
ron_plock = [794604,794695,794787,794773,794635,794725,794719,794716,794695,794658,794561,795046,794560,795046,794560,794560,795697,794591,794586,794819,794588,796658,794818,794818,794558,794655,795044,794557,795043,794811,794811,795042,794758,794906,794901,794897,794627,794865,794691,794676,795047,794658,794560,794560,794560,794815,794815,794560,794822,794822,794587,794819,794818,796658,796658,796649,794558,795043,795043,795043,794556,794567,795760,794427]
ron_ticket = [352272,352267,352272,352262,352269,352226,352246,352249,352264,352250,352251,352252,352258,352256,352258,352259,352359,352392,352427,352447,352653,352665,353488,353804,352270,352271,352275,352276,352287,352288,352291,352292,352279,352276,352274,352270,352247,352247,352248,352262,352259,352253,352254,352254,352261,352265,352266,352269,352528,352589,352593,352644,353805,354249,376025,354296,352278,352278,352284,352285,352296,352322,352338,352343]
plock = [486588,607596,592604,415248,656859,793730,788426,494053,88423,93658,86666,71791,83636,89736,83578,68786,85602,90562,84706,66551,89424,94492,85504,68381,89244,91099,85321,69520,84082,87481,80706,66773,472152,576892,576881,416852,641703,750199,780189,496793,87143,91867,85783,69896,83647,85695,84184,66813,84897,88310,84909,65833,91049,90662,85649,68266,86988,88649,86249,69760,81708,85621,83710,66395]
ticket = [268418,268404,268415,268385,268371,268340,268350,268341,268346,268346,268346,268347,268349,268352,268353,268351,268385,268386,268385,268399,268486,268506,268505,268567,268360,268360,280444,268364,268368,268368,268368,268372,268387,268382,268376,268373,268348,268347,268350,268346,268348,268349,268349,268350,268352,268358,268359,268362,268404,268415,268433,268442,268661,269106,269344,269487,268363,268364,268365,268366,268374,268377,268381,268380]

plt.figure(figsize=(15,5),dpi=100,linewidth = 2)
plt.plot(threads, ron_plock, color="crimson", linestyle="-", linewidth="2", markersize="12", marker=".", label="RON_Plock")
plt.plot(threads, ron_ticket, color="navy", linestyle="-", linewidth="2", markersize="12", marker=".", label="RON_ticket")
plt.plot(threads, plock, color="seagreen", linestyle="-", linewidth="2", markersize="12", marker=".", label="plock")
plt.plot(threads, ticket, color="cornflowerblue", linestyle="-", linewidth="2", markersize="12", marker=".", label="ticket")

plt.xlim(0, 65)

plt.xlabel('threads number on cores', fontsize="18")
plt.ylabel('times to enter CS', fontsize="18")
title = "Times of threads enter CS\n"
plt.suptitle(title,  y=1.02, fontsize="20")
sub = "with 128 threads and remainder section size = 2000"
plt.title(sub, fontsize="16")

plt.legend()
plt.show()

# %%
# oversubscribe
#x_threads = [64,96,128,256,384], ncs_size = 2000
spinlocks = ['ron_plock', 'ron_ticket', 'plock', 'ticket']
thread64 = [1001679, 574381, 442225,389340]
thread96 = [710724, 450310, 243216,307373]
thread128 = [558711,388026,224860,284433]
thread256 = [513083,201713,116897,172947]
thread384 = [352240,141101,80791,125196]

x = np.arange(len(spinlocks))
width = 0.1

plt.figure(figsize=(12,6),dpi=100,linewidth = 2)

plt.bar(x, thread64, width, color='midnightblue', label='64 threads')
plt.bar(x+width, thread96, width, color='darkblue', label='96 threads')
plt.bar(x+width*2, thread128, width, color='royalblue', label='128 threads')
plt.bar(x+width*3, thread256, width, color='cornflowerblue', label='256 threads')
plt.bar(x+width*4, thread384, width, color='lightsteelblue', label='384 threads')

plt.xticks(x + width*5/3 , spinlocks, fontsize="20")
plt.ylabel('locks per second', fontsize="18")
plt.suptitle('Oversubscribe', fontsize="24")
plt.legend(bbox_to_anchor=(1,1), loc='upper left')
plt.show()
